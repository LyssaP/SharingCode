# %%
import numpy as np
import pandas as pd
import xml.etree.ElementTree as ET
import matplotlib.pyplot as plt

# %%
df = pd.read_csv( 'C:/Users/Douglas/Desktop/Python/purchases.csv' )
print(df)
# Out:
#   Unnamed: 0 country  ad_views  items_purchased
# 0     George      US        16                2
# 1       John     CAN        42                1
# 2     Thomas     CAN        32                0
# 3      James      US        13                8
# 4     Andrew     CAN        63                0
# 5     Martin      US        19                5
# 6    William      US        65                7
# 7    Zachary      US        23                3
# 8    Millard     CAN        16                0
# 9   Franklin      US        77                5

# %%
df.to_csv('my_csv_file.csv')

# %%
purchases = pd.read_csv('purchases.csv')
print(purchases)
# Out:
#   Unnamed: 0 country  ad_views  items_purchased
# 0     George      US        16                2
# 1       John     CAN        42                1
# 2     Thomas     CAN        32                0
# 3      James      US        13                8
# 4     Andrew     CAN        63                0
# 5     Martin      US        19                5
# 6    William      US        65                7
# 7    Zachary      US        23                3
# 8    Millard     CAN        16                0
# 9   Franklin      US        77                5

# %%
purchases_two = pd.read_json('purchases.json')
print(purchases_two)
# Out:
#   Unnamed: 0 country  ad_views  items_purchased
# 0     George      US        16                2
# 1       John     CAN        42                1
# 2     Thomas     CAN        32                0
# 3      James      US        13                8
# 4     Andrew     CAN        63                0
# 5     Martin      US        19                5
# 6    William      US        65                7
# 7    Zachary      US        23                3
# 8    Millard     CAN        16                0
# 9   Franklin      US        77                5

# %%
tree = ET.parse('purchases.xml')
root = tree.getroot()
def xml_to_pandas(root):
    result = []
    for row in root:
        row_list = []
        for column in row:
            row_list.append(column.text)
        result.append(row_list)
    return result
xml_purchases = pd.DataFrame(xml_to_pandas(root))
print(xml_purchases)
# Out:
#           0    1   2  3
# 0    George   US  16  2
# 1      John  CAN  42  1
# 2    Thomas  CAN  32  0
# 3     James   US  13  8
# 4    Andrew  CAN  63  0
# 5    Martin   US  19  5
# 6   William   US  65  7
# 7   Zachary   US  23  3
# 8   Millard  CAN  16  0
# 9  Franklin   US  77  5

# %%
with open('poem.txt') as poem_text:
    text = poem_text.readlines()
    print('This file is {} lines long.'.format(len(text)))
    for lines in text:
        print(lines)
# Out:
# This file is 19 lines long.
# Beautiful is better than ugly.
#
# Explicit is better than implicit.
#
# Simple is better than complex.
#
# Complex is better than complicated.
#
# Flat is better than nested.
#
# Sparse is better than dense.
#
# Readability counts.
#
# Special cases aren't special enough to break the rules.
#
# Although practicality beats purity.
#
# Errors should never pass silently.
#
# Unless explicitly silenced.
#
# In the face of ambiguity, refuse the temptation to guess.
#
# There should be one-- and preferably only one --obvious way to do it.
#
# Although that way may not be obvious at first unless you're Dutch.
#
# Now is better than never.
#
# Although never is often better than *right* now.
#
# If the implementation is hard to explain, it's a bad idea.
#
# If the implementation is easy to explain, it may be a good idea.
#
# Namespaces are one honking great idea -- let's do more of those!

# %%
# %matplotlib inline
plt.plot([0,1,2,3,4])

# %%
np.random.seed(1221)
df = pd.DataFrame()
df['rand'] = np.random.rand(100)
df['rand_sqr'] = df['rand']**2
df['rand_shift'] = df['rand']+1
df['counts_sqr'] = df.index**2
df['counts_sqrt'] = np.sqrt(df.index)
plt.plot(df['rand'],color='blue')
plt.plot(df['rand_sqr'], color='cyan')
plt.plot(df['rand_shift'], color='hotpink')
plt.title('LOOK AT THIS GRAAAPH!')
plt.ylabel('Values')
# Out:
# Text(0, 0.5, 'Values')

# %%
plt.scatter(df['rand'],y=df['rand_sqr'],color='red')
plt.scatter(df['rand'],y=df['rand_shift'],color='purple')

# %%
df.plot(kind='scatter',x='counts_sqr',y='counts_sqrt',color='orange')
df.plot(kind='line')
